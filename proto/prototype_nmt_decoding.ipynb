# %%
# prototype constrained decoding with INMT models

# build the simplest possible interface to a trained NMT model
# define the payload for NMT hypotheses

# the interface between NMT and constrained decoding needs to know how to create ConstrainedHypothesis objects

import copy

import numpy as np
from collections import defaultdict, OrderedDict

from constrained_decoding import ConstraintHypothesis
from constrained_decoding.translation_model import AbstractConstrainedTM

from nn_imt import IMTPredictor
from neural_mt.machine_translation.configurations import get_config

# %%
IMT_CONFIGURATION_FILE = '/home/chris/projects/neural_imt/experiments/configs/demos/en-de/en-de_interactive_demo.yaml'

# %%
class NeuralTranslationModel(AbstractConstrainedTM):
    
    def __init__(self, config_file):
        """Intitialize the model according to user provided configuration
        
        - follow the style of BeamSearch, but remove the search logic
        - build the graph and load the parameters (i.e. create a Predictor and expose the right functions)
        """
        
        self.imt_model = IMTPredictor(get_config(config_file))
        self.imt_beam_search = self.imt_model.beam_search 
        
    def build_input_representations(self, source_tokens, constraint_token_seqs):
        """Encode the input sequences using the source and target word-->idx maps"""
        # TODO: add tokenization, subword encoding

        source_seq = self.imt_model.map_idx_or_unk(source_tokens,
                                                   self.imt_model.src_vocab,
                                                   self.imt_model.unk_idx)

        # we assume that constraints are in the target language
        constraint_seqs = []
        for token_seq in constraint_token_seqs:
            token_idxs = self.imt_model.map_idx_or_unk(token_seq,
                                                       self.imt_model.trg_vocab,
                                                       self.imt_model.unk_idx)
            constraint_seqs.append(token_idxs)
        
        source_seq = np.tile(source_seq, (1, 1))
        
        # TODO: we'll need to tile constraint_seqs up to beam_size for NMT models
        #input_ = numpy.tile(seq, (self.exp_config['beam_size'], 1))
    
        return (source_seq, constraint_seqs)
        
    # TODO: remove target_prefix from args (see below)
    def start_hypothesis(self, source_seq, target_prefix, constraints, coverage=None):
        """
        Build the start hyp for a neural translation model.
        Models may or may not use constraints. I.e. by modeling
        the probability of generating vs. copying from the constraints. 
        
        """
        
        # TODO: there SHOULD BE no self.target_sampling_input because we don't use the prefix representation in constrained
        # input_values = {:class:`~theano.Variable`: :class:`~numpy.ndarray`}
        input_values = {
            self.imt_model.source_sampling_input: source_seq,
            self.imt_model.target_sampling_input: target_prefix
        }
        
        # Note that the initial input of an NMT model is currently implicit (i.e. Readout.initial_input)
        # TODO: how to explicitly encode the NMT start hypothesis
        contexts, states, beam_size = self.imt_beam_search.compute_initial_states_and_contexts(inputs=input_values)

        # Note: explicit initialization of coverage
        coverage = [np.zeros(l, dtype='int16') for l in [len(s) for s in constraints]]
    
        # the payload contains everything that the next timestep will need to generate another output
        payload = {
            'contexts': contexts,
            'states': states,
            # input_values is here because of a bug in getting beam-size from the graph
            'input_values': input_values
        }
    
        start_hyp = ConstraintHypothesis(
            token=None,
            score=None, 
            coverage=coverage,
            constraints=constraints,
            payload=payload,
            backpointer=None,
            constraint_index=None,
            unfinished_constraint=False
        )
        
        return start_hyp
        
    # TODO: if score is None, replace, don't add in log space
    # TODO: if token is None, and this is the start hypothesis, do nothing
    # TODO: any tiling logic idiosyncrasies for IMT beam search need to be encapsulated within this class
    def generate(self, hyp, n_best):
        """
        Note: the `n_best` parameter here is only used to limit the number of hypothesis objects that are generated
        from the input hyp, the beam implementation may specify a different `n_best`
        
        
        """
        
        logprobs = self.imt_beam_search.compute_logprobs(hyp.payload['input_values'],
                                                         hyp.payload['contexts'],
                                                         hyp.payload['states'])
        
        # TODO: assert that logprobs only has one row, so we can flatten it and not lose anything
        n_best_outputs = np.argsort(logprobs.flatten())[:n_best]
        chosen_costs = logprobs.flatten()[n_best_outputs]
        
        # generate n_best ConstrainedHypothesis for each item on the beam, return them all
        # argsort logprobs
        
        payload = hyp.payload
        
        # Note: it's critical to use the OrderedDict here, otherwise args will get out of order in theano funcs
        tiled_payload = defaultdict(OrderedDict)
        tiled_payload['contexts']['attended'] = np.tile(payload['contexts']['attended'], (1, n_best, 1))
        tiled_payload['contexts']['attended_mask'] = np.tile(payload['contexts']['attended_mask'], (1, n_best))

#         [(k, start_hyp.payload['contexts'][k].shape) for k in start_hyp.payload['contexts'].keys()]
#         [('attended', (6, 1, 2000)), ('attended_mask', (6, 1))]

        tiled_payload['states']['outputs'] = np.tile(payload['states']['outputs'], n_best)
        tiled_payload['states']['states'] = np.tile(payload['states']['states'], (n_best, 1))
        tiled_payload['states']['weights'] = np.tile(payload['states']['weights'], (n_best, 1))
        tiled_payload['states']['weighted_averages'] = np.tile(payload['states']['weighted_averages'], (n_best, 1))

# [(k, start_hyp.payload['states'][k].shape) for k in start_hyp.payload['states'].keys()]
# [('outputs', (1,)),
#  ('states', (1, 1000)),
#  ('weights', (1, 6)),
#  ('weighted_averages', (1, 2000))]

        tiled_payload['input_values'][self.imt_model.source_sampling_input] = np.tile(payload['input_values'][self.imt_model.source_sampling_input], 
                                                                                      (n_best, 1))
        tiled_payload['input_values'][self.imt_model.target_sampling_input] = np.tile(payload['input_values'][self.imt_model.target_sampling_input], 
                                                                                      (n_best, 1))

# [(k, start_hyp.payload['input_values'][k].shape) for k in start_hyp.payload['input_values'].keys()]
# [(sampling_input, (1, 6)), (sampling_target_prefix, (1, 2))]


        # Now we need to tile the previous hyp values to make this work
        next_states = self.imt_beam_search.compute_next_states(tiled_payload['input_values'],
                                                               tiled_payload['contexts'],
                                                               tiled_payload['states'],
                                                               n_best_outputs)

        # create ContstrainedHypothesis objects from these states (tile back down to one)
        new_hyps = []
        for hyp_idx in range(n_best):
            new_payload = defaultdict(OrderedDict)
            new_payload['contexts'] = payload['contexts']

            new_payload['states']['outputs'] = np.atleast_1d(next_states['outputs'][hyp_idx])
            new_payload['states']['states'] = np.atleast_2d(next_states['states'][hyp_idx])
            new_payload['states']['weights'] = np.atleast_2d(next_states['weights'][hyp_idx])
            new_payload['states']['weighted_averages'] = np.atleast_2d(next_states['weighted_averages'][hyp_idx])
# [('outputs', (1,)),
#  ('states', (1, 1000)),
#  ('weights', (1, 6)),
#  ('weighted_averages', (1, 2000))]
            
            
            new_payload['input_values'] = hyp.payload['input_values']
                
#             TODO: account for EOS continuations
            if hyp.score is not None:
                next_score = hyp.score + chosen_costs[hyp_idx]
            else:
                # hyp.score is None for the start hyp
                next_score = chosen_costs[hyp_idx]
                
            new_hyp = ConstraintHypothesis(
                token=self.imt_model.trg_ivocab[n_best_outputs[hyp_idx]],
                score=next_score, 
                coverage=copy.deepcopy(hyp.coverage),
                constraints=hyp.constraints,
                payload=new_payload,
                backpointer=hyp,
                constraint_index=None,
                unfinished_constraint=False
            )

            new_hyps.append(new_hyp)
            
        return new_hyps
        
        
        # The additional dim (`None`) is needed to maintain 2d, and to
        # make the broadcasting of `logprobs * all_masks[-1, :, None] work
#         next_costs = (all_costs[-1, :, None] +
#                       logprobs * all_masks[-1, :, None])
#         (finished,) = numpy.where(all_masks[-1] == 0)
        
        # WORKING: see if we can generate one timestep from start hyp
        
        # we always start from the beginning of the sequence, so we always need initial states
        # the initial states and contexts are the payload of the "start_hyp"
        # states['outputs']
        # states['weights']
        
        # This array will store all generated outputs, including those from
        # previous step and those from already finished sequences.
        #all_outputs = states['outputs'][None, :]
        #all_masks = numpy.ones_like(all_outputs, dtype=config.floatX)
        #all_costs = numpy.zeros_like(all_outputs, dtype=config.floatX)

        # Chris: get the glimpse weights as well
        #prev_glimpses = states['weights'][None, :]
        #all_glimpses = numpy.zeros_like(prev_glimpses, dtype=config.floatX)

        # Note: confidence at timestep zero is always = 1
        #all_confidences = numpy.ones_like(all_outputs, dtype=config.floatX)
            
    def generate_constrained(self, hyp):
        pass
    
    def continue_constrained(self, hyp):
        pass

# %%
# the mask performs several functions, which serve to tell us the point when a hypothesis starts to end with <EOS>

# %%
imt_tm = NeuralTranslationModel(IMT_CONFIGURATION_FILE)
# Out:
# WARNING:blocks.bricks.recurrent:unknown input sequencegenerator_generate_target_prefix
#
# Your function uses a non-shared variable other than those given by scan explicitly. That can significantly slow down `tensor.grad` call. Did you forget to declare it in `contexts`?
# INFO:machine_translation.checkpoint:Note that the delimeter for parameter loading is currently hacked
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /bidirectionalencoder/bidirectionalwmt15/backward.initial_state
# INFO:machine_translation.checkpoint: Loaded to CG (2000,)        : /bidirectionalencoder/back_fork/fork_gate_inputs.b
# INFO:machine_translation.checkpoint: Loaded to CG (300, 2000)    : /bidirectionalencoder/back_fork/fork_gate_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /bidirectionalencoder/back_fork/fork_inputs.b
# INFO:machine_translation.checkpoint: Loaded to CG (300, 1000)    : /bidirectionalencoder/back_fork/fork_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /bidirectionalencoder/bidirectionalwmt15/forward.initial_state
# INFO:machine_translation.checkpoint: Loaded to CG (2000,)        : /bidirectionalencoder/fwd_fork/fork_gate_inputs.b
# INFO:machine_translation.checkpoint: Loaded to CG (300, 2000)    : /bidirectionalencoder/fwd_fork/fork_gate_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /bidirectionalencoder/fwd_fork/fork_inputs.b
# INFO:machine_translation.checkpoint: Loaded to CG (300, 1000)    : /bidirectionalencoder/fwd_fork/fork_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /decoder/sequencegenerator/fork/fork_inputs.b
# INFO:machine_translation.checkpoint: Loaded to CG (300, 1000)    : /decoder/sequencegenerator/fork/fork_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (2000,)        : /decoder/sequencegenerator/fork/fork_gate_inputs.b
# INFO:machine_translation.checkpoint: Loaded to CG (300, 2000)    : /decoder/sequencegenerator/fork/fork_gate_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /decoder/sequencegenerator/att_trans/attention/preprocess.b
# INFO:machine_translation.checkpoint: Loaded to CG (2000, 1000)   : /decoder/sequencegenerator/att_trans/attention/preprocess.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /decoder/sequencegenerator/att_trans/decoder/state_initializer/linear_0.b
# INFO:machine_translation.checkpoint: Loaded to CG (80000, 300)   : /bidirectionalencoder/embeddings.W
# INFO:machine_translation.checkpoint: Loaded to CG (90000, 300)   : /decoder/sequencegenerator/readout/lookupfeedbackwmt15/lookuptable.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 2000)   : /bidirectionalencoder/bidirectionalwmt15/forward.state_to_gates
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1000)   : /bidirectionalencoder/bidirectionalwmt15/forward.state_to_state
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 2000)   : /bidirectionalencoder/bidirectionalwmt15/backward.state_to_gates
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1000)   : /bidirectionalencoder/bidirectionalwmt15/backward.state_to_state
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1000)   : /decoder/sequencegenerator/att_trans/decoder/state_initializer/linear_0.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 2000)   : /decoder/sequencegenerator/att_trans/decoder.state_to_gates
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1000)   : /decoder/sequencegenerator/att_trans/attention/state_trans/transform_states.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1)      : /decoder/sequencegenerator/att_trans/attention/energy_comp/linear.W
# INFO:machine_translation.checkpoint: Loaded to CG (2000, 2000)   : /decoder/sequencegenerator/att_trans/distribute/fork_gate_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1000)   : /decoder/sequencegenerator/att_trans/decoder.state_to_state
# INFO:machine_translation.checkpoint: Loaded to CG (2000, 1000)   : /decoder/sequencegenerator/att_trans/distribute/fork_inputs.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000, 1000)   : /decoder/sequencegenerator/readout/merge/transform_states.W
# INFO:machine_translation.checkpoint: Loaded to CG (300, 1000)    : /decoder/sequencegenerator/readout/merge/transform_feedback.W
# INFO:machine_translation.checkpoint: Loaded to CG (2000, 1000)   : /decoder/sequencegenerator/readout/merge/transform_weighted_averages.W
# INFO:machine_translation.checkpoint: Loaded to CG (1000,)        : /decoder/sequencegenerator/readout/initializablefeedforwardsequence/maxout_bias.b
# INFO:machine_translation.checkpoint: Loaded to CG (500, 300)     : /decoder/sequencegenerator/readout/initializablefeedforwardsequence/softmax0.W
# INFO:machine_translation.checkpoint: Loaded to CG (300, 90000)   : /decoder/sequencegenerator/readout/initializablefeedforwardsequence/softmax1.W
# INFO:machine_translation.checkpoint: Loaded to CG (90000,)       : /decoder/sequencegenerator/readout/initializablefeedforwardsequence/softmax1.b
# WARNING:machine_translation.checkpoint: Parameter does not exist: /decoder/sequencegenerator/initializablefeedforwardsequence/confidence_model1.W
# WARNING:machine_translation.checkpoint: Parameter does not exist: /decoder/sequencegenerator/initializablefeedforwardsequence/confidence_model1.b
# WARNING:machine_translation.checkpoint: Parameter does not exist: /decoder/sequencegenerator/initializablefeedforwardsequence/confidence_model2.W
# WARNING:machine_translation.checkpoint: Parameter does not exist: /decoder/sequencegenerator/initializablefeedforwardsequence/confidence_model2.b
# WARNING:machine_translation.checkpoint: Parameter does not exist: /decoder/sequencegenerator/initializablefeedforwardsequence/confidence_model3.W
# WARNING:machine_translation.checkpoint: Parameter does not exist: /decoder/sequencegenerator/initializablefeedforwardsequence/confidence_model3.b
# INFO:machine_translation.checkpoint: Number of parameters loaded for computation graph: 37
# loss function is: cross_entropy

# %%
source_input = u'<S> This is a test </S>'.split()
target_prefix = u'<S> Dies'.split()
constraint_seq = [target_prefix]
    
source_, constraints_ = imt_tm.build_input_representations(source_input, constraint_seq)

# TODO: this is a hack until we remove the target_prefix completely from the graph
target_prefix_ = imt_tm.imt_model.map_idx_or_unk(target_prefix,
                                                 imt_tm.imt_model.trg_vocab,
                                                 imt_tm.imt_model.unk_idx)

target_prefix_ = np.tile(target_prefix_, (1, 1))

# %%
len(source_input)
source_
# Out:
# array([[    0,    60,    10,     9,  1188, 79999]])

# %%
# TODO: directly use NMT decoder, or remove target_prefix from IMT graph via config
# TODO: this is a dependency question -- which repo will we rely on??
start_hyp = imt_tm.start_hypothesis(source_seq=source_, target_prefix=target_prefix_, 
                                       constraints=constraint_seq)

# %%
t = imt_tm.generate(start_hyp, n_best=10)
nts = [imt_tm.generate(h, n_best=10) for h in t]
nnts = [[imt_tm.generate(h, n_best=10) for h in t] for t in nts]

# %%
[[[h.sequence for h in stack3] for stack3 in stack2] for stack2 in nnts]
# Out:
# [[[[None, 'ist', 'ein', 'Test'],
#    [None, 'ist', 'ein', 'Test@@'],
#    [None, 'ist', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'ist', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'ist', 'ein', 'Prozess'],
#    [None, 'ist', 'ein', 'Tag'],
#    [None, 'ist', 'ein', 'Grundsatz'],
#    [None, 'ist', 'ein', 'Bericht'],
#    [None, 'ist', 'ein', 'Pr\xc3\xbcfungs@@'],
#    [None, 'ist', 'ein', 'test']],
#   [[None, 'ist', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'ist', 'eine', 'Test@@'],
#    [None, 'ist', 'eine', 'Probe'],
#    [None, 'ist', 'eine', 'Untersuchung'],
#    [None, 'ist', 'eine', 'Frage'],
#    [None, 'ist', 'eine', 'Liste'],
#    [None, 'ist', 'eine', 'Studie'],
#    [None, 'ist', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'ist', 'eine', 'Stich@@'],
#    [None, 'ist', 'eine', 'Tests']],
#   [[None, 'ist', 'die', 'Probe'],
#    [None, 'ist', 'die', 'Pr\xc3\xbcfung'],
#    [None, 'ist', 'die', 'Frage'],
#    [None, 'ist', 'die', 'Test@@'],
#    [None, 'ist', 'die', 'Konsequenz'],
#    [None, 'ist', 'die', 'Liste'],
#    [None, 'ist', 'die', 'Durchf\xc3\xbchrung'],
#    [None, 'ist', 'die', 'Empfehlung'],
#    [None, 'ist', 'die', 'vorliegende'],
#    [None, 'ist', 'die', 'Annahme']],
#   [[None, 'ist', 'einen', 'Test'],
#    [None, 'ist', 'einen', 'Test@@'],
#    [None, 'ist', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'ist', 'einen', 'Tag'],
#    [None, 'ist', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'ist', 'einen', 'test'],
#    [None, 'ist', 'einen', 'Bericht'],
#    [None, 'ist', 'einen', 'stest'],
#    [None, 'ist', 'einen', 'Prozess'],
#    [None, 'ist', 'einen', 'Pr\xc3\xbcfung']],
#   [[None, 'ist', 'es', 'ein'],
#    [None, 'ist', 'es', 'eine'],
#    [None, 'ist', 'es', ','],
#    [None, 'ist', 'es', 'um'],
#    [None, 'ist', 'es', 'zu'],
#    [None, 'ist', 'es', 'vor'],
#    [None, 'ist', 'es', 'einer'],
#    [None, 'ist', 'es', '.'],
#    [None, 'ist', 'es', 'mit'],
#    [None, 'ist', 'es', 'eines']],
#   [[None, 'ist', 'einer', 'Pr\xc3\xbcfung'],
#    [None, 'ist', 'einer', 'Test@@'],
#    [None, 'ist', 'einer', 'der'],
#    [None, 'ist', 'einer', 'Test'],
#    [None, 'ist', 'einer', 'von'],
#    [None, 'ist', 'einer', 'test'],
#    [None, 'ist', 'einer', 'Pr\xc3\xbcf@@'],
#    [None, 'ist', 'einer', 'Probe'],
#    [None, 'ist', 'einer', 'Pr\xc3\xbcfstand'],
#    [None, 'ist', 'einer', 'Tests']],
#   [[None, 'ist', 'der', 'Test'],
#    [None, 'ist', 'der', 'Fall'],
#    [None, 'ist', 'der', 'Test@@'],
#    [None, 'ist', 'der', 'Pr\xc3\xbcfstand'],
#    [None, 'ist', 'der', 'Grundsatz'],
#    [None, 'ist', 'der', 'Pr\xc3\xbcf@@'],
#    [None, 'ist', 'der', 'Tag'],
#    [None, 'ist', 'der', 'Bericht'],
#    [None, 'ist', 'der', 'Versuch'],
#    [None, 'ist', 'der', 'beste']],
#   [[None, 'ist', 'eines', 'der'],
#    [None, 'ist', 'eines', 'Tages'],
#    [None, 'ist', 'eines', 'Test'],
#    [None, 'ist', 'eines', 'Test@@'],
#    [None, 'ist', 'eines', 'von'],
#    [None, 'ist', 'eines', 'unserer'],
#    [None, 'ist', 'eines', 'pr\xc3\xbcfen'],
#    [None, 'ist', 'eines', 'test'],
#    [None, 'ist', 'eines', 'Tests'],
#    [None, 'ist', 'eines', ',']],
#   [[None, 'ist', 'vor', 'allem'],
#    [None, 'ist', 'vor', 'einem'],
#    [None, 'ist', 'vor', 'einer'],
#    [None, 'ist', 'vor', 'Gericht'],
#    [None, 'ist', 'vor', 'dem'],
#    [None, 'ist', 'vor', 'Ort'],
#    [None, 'ist', 'vor', 'uns'],
#    [None, 'ist', 'vor', 'der'],
#    [None, 'ist', 'vor', 'kurzem'],
#    [None, 'ist', 'vor', 'allen']],
#   [[None, 'ist', 'das', 'eine'],
#    [None, 'ist', 'das', 'Thema'],
#    [None, 'ist', 'das', 'Verfahren'],
#    [None, 'ist', 'das', 'Prinzip'],
#    [None, 'ist', 'das', 'ein'],
#    [None, 'ist', 'das', 'Test@@'],
#    [None, 'ist', 'das', 'Eine'],
#    [None, 'ist', 'das', 'Gebot'],
#    [None, 'ist', 'das', '</S>'],
#    [None, 'ist', 'das', 'Test']]],
#  [[[None, 'wird', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'wird', 'eine', 'Test@@'],
#    [None, 'wird', 'eine', 'Probe'],
#    [None, 'wird', 'eine', 'Untersuchung'],
#    [None, 'wird', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'wird', 'eine', 'Studie'],
#    [None, 'wird', 'eine', 'Tests'],
#    [None, 'wird', 'eine', 'Empfehlung'],
#    [None, 'wird', 'eine', 'Liste'],
#    [None, 'wird', 'eine', 'Stich@@']],
#   [[None, 'wird', 'ein', 'Test'],
#    [None, 'wird', 'ein', 'Test@@'],
#    [None, 'wird', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'wird', 'ein', 'Verfahren'],
#    [None, 'wird', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'wird', 'ein', 'test'],
#    [None, 'wird', 'ein', 'Pr\xc3\xbcfungs@@'],
#    [None, 'wird', 'ein', 'Prozess'],
#    [None, 'wird', 'ein', 'stest'],
#    [None, 'wird', 'ein', 'Tag']],
#   [[None, 'wird', 'vor', 'einem'],
#    [None, 'wird', 'vor', 'Gericht'],
#    [None, 'wird', 'vor', 'allem'],
#    [None, 'wird', 'vor', 'einer'],
#    [None, 'wird', 'vor', 'dem'],
#    [None, 'wird', 'vor', 'Ort'],
#    [None, 'wird', 'vor', 'uns'],
#    [None, 'wird', 'vor', 'der'],
#    [None, 'wird', 'vor', 'kurzem'],
#    [None, 'wird', 'vor', 'den']],
#   [[None, 'wird', 'von', 'einem'],
#    [None, 'wird', 'von', 'uns'],
#    [None, 'wird', 'von', 'der'],
#    [None, 'wird', 'von', 'den'],
#    [None, 'wird', 'von', 'einer'],
#    [None, 'wird', 'von', 'Anfang'],
#    [None, 'wird', 'von', 'unseren'],
#    [None, 'wird', 'von', 'Ihnen'],
#    [None, 'wird', 'von', 'Test@@'],
#    [None, 'wird', 'von', 'dem']],
#   [[None, 'wird', 'auf', 'jeden'],
#    [None, 'wird', 'auf', 'den'],
#    [None, 'wird', 'auf', 'der'],
#    [None, 'wird', 'auf', 'Test@@'],
#    [None, 'wird', 'auf', 'einen'],
#    [None, 'wird', 'auf', 'die'],
#    [None, 'wird', 'auf', 'einem'],
#    [None, 'wird', 'auf', 'Probe'],
#    [None, 'wird', 'auf', 'dem'],
#    [None, 'wird', 'auf', 'eine']],
#   [[None, 'wird', 'einen', 'Test'],
#    [None, 'wird', 'einen', 'Test@@'],
#    [None, 'wird', 'einen', 'Tag'],
#    [None, 'wird', 'einen', 'test'],
#    [None, 'wird', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'wird', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'wird', 'einen', 'stest'],
#    [None, 'wird', 'einen', 'Bericht'],
#    [None, 'wird', 'einen', 'Prozess'],
#    [None, 'wird', 'einen', 'Pr\xc3\xbcfung']],
#   [[None, 'wird', 'in', 'einem'],
#    [None, 'wird', 'in', 'der'],
#    [None, 'wird', 'in', 'den'],
#    [None, 'wird', 'in', 'einer'],
#    [None, 'wird', 'in', 'unseren'],
#    [None, 'wird', 'in', 'einen'],
#    [None, 'wird', 'in', 'Test@@'],
#    [None, 'wird', 'in', 'die'],
#    [None, 'wird', 'in', 'erster'],
#    [None, 'wird', 'in', 'jedem']],
#   [[None, 'wird', 'zur', 'Pr\xc3\xbcfung'],
#    [None, 'wird', 'zur', 'Zeit'],
#    [None, 'wird', 'zur', 'Probe'],
#    [None, 'wird', 'zur', 'Test@@'],
#    [None, 'wird', 'zur', 'Konsequenz'],
#    [None, 'wird', 'zur', 'Folge'],
#    [None, 'wird', 'zur', 'Tat'],
#    [None, 'wird', 'zur', 'Durchf\xc3\xbchrung'],
#    [None, 'wird', 'zur', 'Untersuchung'],
#    [None, 'wird', 'zur', 'Gesch\xc3\xa4ftsordnung']],
#   [[None, 'wird', 'mit', 'einem'],
#    [None, 'wird', 'mit', 'einer'],
#    [None, 'wird', 'mit', 'dem'],
#    [None, 'wird', 'mit', 'der'],
#    [None, 'wird', 'mit', 'Test@@'],
#    [None, 'wird', 'mit', 'den'],
#    [None, 'wird', 'mit', 'Pr\xc3\xbcfung'],
#    [None, 'wird', 'mit', 'uns'],
#    [None, 'wird', 'mit', 'Beweisen'],
#    [None, 'wird', 'mit', 'Blick']],
#   [[None, 'wird', 'auch', 'eine'],
#    [None, 'wird', 'auch', 'f\xc3\xbcr'],
#    [None, 'wird', 'auch', 'ein'],
#    [None, 'wird', 'auch', 'zur'],
#    [None, 'wird', 'auch', 'bei'],
#    [None, 'wird', 'auch', 'auf'],
#    [None, 'wird', 'auch', 'in'],
#    [None, 'wird', 'auch', 'durch'],
#    [None, 'wird', 'auch', 'mit'],
#    [None, 'wird', 'auch', 'von']]],
#  [[[None, 'stellt', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'stellt', 'eine', 'Test@@'],
#    [None, 'stellt', 'eine', 'Probe'],
#    [None, 'stellt', 'eine', 'Frage'],
#    [None, 'stellt', 'eine', 'Untersuchung'],
#    [None, 'stellt', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'stellt', 'eine', 'Liste'],
#    [None, 'stellt', 'eine', 'Bewertung'],
#    [None, 'stellt', 'eine', 'Empfehlung'],
#    [None, 'stellt', 'eine', 'Konsequenz']],
#   [[None, 'stellt', 'einen', 'Test'],
#    [None, 'stellt', 'einen', 'Test@@'],
#    [None, 'stellt', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'stellt', 'einen', 'test'],
#    [None, 'stellt', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'stellt', 'einen', 'Tag'],
#    [None, 'stellt', 'einen', 'Pr\xc3\xbcfung'],
#    [None, 'stellt', 'einen', 'Prozess'],
#    [None, 'stellt', 'einen', 'stest'],
#    [None, 'stellt', 'einen', 'Bericht']],
#   [[None, 'stellt', 'ein', 'Test@@'],
#    [None, 'stellt', 'ein', 'Test'],
#    [None, 'stellt', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'stellt', 'ein', 'Verfahren'],
#    [None, 'stellt', 'ein', 'Pr\xc3\xbcfungs@@'],
#    [None, 'stellt', 'ein', '</S>'],
#    [None, 'stellt', 'ein', 'Ende'],
#    [None, 'stellt', 'ein', 'test'],
#    [None, 'stellt', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'stellt', 'ein', 'Thema']],
#   [[None, 'stellt', 'sich', 'vor'],
#    [None, 'stellt', 'sich', 'auf'],
#    [None, 'stellt', 'sich', 'eine'],
#    [None, 'stellt', 'sich', 'ein'],
#    [None, 'stellt', 'sich', 'f\xc3\xbcr'],
#    [None, 'stellt', 'sich', 'aus'],
#    [None, 'stellt', 'sich', 'als'],
#    [None, 'stellt', 'sich', 'in'],
#    [None, 'stellt', 'sich', 'hier'],
#    [None, 'stellt', 'sich', 'einen']],
#   [[None, 'stellt', 'die', 'Frage'],
#    [None, 'stellt', 'die', 'Pr\xc3\xbcfung'],
#    [None, 'stellt', 'die', 'Probe'],
#    [None, 'stellt', 'die', 'Test@@'],
#    [None, 'stellt', 'die', 'Notwendigkeit'],
#    [None, 'stellt', 'die', 'Konsequenz'],
#    [None, 'stellt', 'die', 'Situation'],
#    [None, 'stellt', 'die', 'Zeit'],
#    [None, 'stellt', 'die', 'Durchf\xc3\xbchrung'],
#    [None, 'stellt', 'die', 'Liste']],
#   [[None, 'stellt', 'es', 'vor'],
#    [None, 'stellt', 'es', 'sich'],
#    [None, 'stellt', 'es', 'einen'],
#    [None, 'stellt', 'es', 'eine'],
#    [None, 'stellt', 'es', 'ein'],
#    [None, 'stellt', 'es', 'f\xc3\xbcr'],
#    [None, 'stellt', 'es', 'auf'],
#    [None, 'stellt', 'es', 'an'],
#    [None, 'stellt', 'es', 'in'],
#    [None, 'stellt', 'es', 'dar']],
#   [[None, 'stellt', 'auf', 'einen'],
#    [None, 'stellt', 'auf', 'jeden'],
#    [None, 'stellt', 'auf', 'den'],
#    [None, 'stellt', 'auf', 'die'],
#    [None, 'stellt', 'auf', 'der'],
#    [None, 'stellt', 'auf', 'diesen'],
#    [None, 'stellt', 'auf', 'eine'],
#    [None, 'stellt', 'auf', 'einem'],
#    [None, 'stellt', 'auf', 'sich'],
#    [None, 'stellt', 'auf', 'unseren']],
#   [[None, 'stellt', 'vor', 'einem'],
#    [None, 'stellt', 'vor', 'uns'],
#    [None, 'stellt', 'vor', ','],
#    [None, 'stellt', 'vor', 'allem'],
#    [None, 'stellt', 'vor', 'sich'],
#    [None, 'stellt', 'vor', 'einer'],
#    [None, 'stellt', 'vor', '.'],
#    [None, 'stellt', 'vor', 'dem'],
#    [None, 'stellt', 'vor', 'den'],
#    [None, 'stellt', 'vor', 'einen']],
#   [[None, 'stellt', 'den', 'Test'],
#    [None, 'stellt', 'den', 'Tag'],
#    [None, 'stellt', 'den', 'Pr\xc3\xbcfstand'],
#    [None, 'stellt', 'den', 'Fall'],
#    [None, 'stellt', 'den', 'Bericht'],
#    [None, 'stellt', 'den', 'Proze\xc3\x9f'],
#    [None, 'stellt', 'den', 'Anschein'],
#    [None, 'stellt', 'den', 'Stand'],
#    [None, 'stellt', 'den', 'Grundstein'],
#    [None, 'stellt', 'den', 'Auftrag']],
#   [[None, 'stellt', 'f\xc3\xbcr', 'einen'],
#    [None, 'stellt', 'f\xc3\xbcr', 'uns'],
#    [None, 'stellt', 'f\xc3\xbcr', 'die'],
#    [None, 'stellt', 'f\xc3\xbcr', 'den'],
#    [None, 'stellt', 'f\xc3\xbcr', 'sich'],
#    [None, 'stellt', 'f\xc3\xbcr', 'eine'],
#    [None, 'stellt', 'f\xc3\xbcr', 'jeden'],
#    [None, 'stellt', 'f\xc3\xbcr', 'diesen'],
#    [None, 'stellt', 'f\xc3\xbcr', 'ihn'],
#    [None, 'stellt', 'f\xc3\xbcr', 'ein']]],
#  [[[None, 'geht', 'um', 'einen'],
#    [None, 'geht', 'um', 'eine'],
#    [None, 'geht', 'um', 'ein'],
#    [None, 'geht', 'um', 'die'],
#    [None, 'geht', 'um', 'den'],
#    [None, 'geht', 'um', 'das'],
#    [None, 'geht', 'um', '</S>'],
#    [None, 'geht', 'um', 'unsere'],
#    [None, 'geht', 'um', 'es'],
#    [None, 'geht', 'um', 'diesen']],
#   [[None, 'geht', 'auf', 'die'],
#    [None, 'geht', 'auf', 'einen'],
#    [None, 'geht', 'auf', 'den'],
#    [None, 'geht', 'auf', 'jeden'],
#    [None, 'geht', 'auf', 'eine'],
#    [None, 'geht', 'auf', 'ein'],
#    [None, 'geht', 'auf', 'das'],
#    [None, 'geht', 'auf', 'unsere'],
#    [None, 'geht', 'auf', 'diesen'],
#    [None, 'geht', 'auf', 'unseren']],
#   [[None, 'geht', 'hier', 'um'],
#    [None, 'geht', 'hier', 'auf'],
#    [None, 'geht', 'hier', '</S>'],
#    [None, 'geht', 'hier', 'vor'],
#    [None, 'geht', 'hier', 'nicht'],
#    [None, 'geht', 'hier', '.'],
#    [None, 'geht', 'hier', 'nur'],
#    [None, 'geht', 'hier', 'zur'],
#    [None, 'geht', 'hier', 'bei'],
#    [None, 'geht', 'hier', 'zu']],
#   [[None, 'geht', 'nicht', 'um'],
#    [None, 'geht', 'nicht', '</S>'],
#    [None, 'geht', 'nicht', 'nur'],
#    [None, 'geht', 'nicht', 'auf'],
#    [None, 'geht', 'nicht', 'mehr'],
#    [None, 'geht', 'nicht', '.'],
#    [None, 'geht', 'nicht', 'aus'],
#    [None, 'geht', 'nicht', 'zur'],
#    [None, 'geht', 'nicht', 'mit'],
#    [None, 'geht', 'nicht', 'an']],
#   [[None, 'geht', 'es', 'um'],
#    [None, 'geht', 'es', 'hier'],
#    [None, 'geht', 'es', 'bei'],
#    [None, 'geht', 'es', 'vor'],
#    [None, 'geht', 'es', 'nicht'],
#    [None, 'geht', 'es', 'aus'],
#    [None, 'geht', 'es', 'auf'],
#    [None, 'geht', 'es', 'als'],
#    [None, 'geht', 'es', ','],
#    [None, 'geht', 'es', 'in']],
#   [[None, 'geht', 'vor', 'allem'],
#    [None, 'geht', 'vor', 'einem'],
#    [None, 'geht', 'vor', 'uns'],
#    [None, 'geht', 'vor', '.'],
#    [None, 'geht', 'vor', ','],
#    [None, 'geht', 'vor', 'dem'],
#    [None, 'geht', 'vor', 'einer'],
#    [None, 'geht', 'vor', 'Ort'],
#    [None, 'geht', 'vor', 'der'],
#    [None, 'geht', 'vor', 'Gericht']],
#   [[None, 'geht', 'bei', 'uns'],
#    [None, 'geht', 'bei', 'einem'],
#    [None, 'geht', 'bei', 'der'],
#    [None, 'geht', 'bei', 'den'],
#    [None, 'geht', 'bei', 'diesen'],
#    [None, 'geht', 'bei', 'einer'],
#    [None, 'geht', 'bei', 'unseren'],
#    [None, 'geht', 'bei', 'einen'],
#    [None, 'geht', 'bei', 'diesem'],
#    [None, 'geht', 'bei', 'dem']],
#   [[None, 'geht', 'zu', 'einem'],
#    [None, 'geht', 'zu', 'einer'],
#    [None, 'geht', 'zu', 'Lasten'],
#    [None, 'geht', 'zu', 'den'],
#    [None, 'geht', 'zu', 'der'],
#    [None, 'geht', 'zu', 'uns'],
#    [None, 'geht', 'zu', 'Hause'],
#    [None, 'geht', 'zu', 'diesen'],
#    [None, 'geht', 'zu', 'einen'],
#    [None, 'geht', 'zu', 'dem']],
#   [[None, 'geht', 'nur', 'um'],
#    [None, 'geht', 'nur', 'auf'],
#    [None, 'geht', 'nur', 'mit'],
#    [None, 'geht', 'nur', 'darum'],
#    [None, 'geht', 'nur', 'an'],
#    [None, 'geht', 'nur', 'zur'],
#    [None, 'geht', 'nur', 'bei'],
#    [None, 'geht', 'nur', 'f\xc3\xbcr'],
#    [None, 'geht', 'nur', 'dann'],
#    [None, 'geht', 'nur', 'noch']],
#   [[None, 'geht', 'ein', 'Test'],
#    [None, 'geht', 'ein', 'Test@@'],
#    [None, 'geht', 'ein', '.'],
#    [None, 'geht', 'ein', '</S>'],
#    [None, 'geht', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'geht', 'ein', 'Prozess'],
#    [None, 'geht', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'geht', 'ein', 'test'],
#    [None, 'geht', 'ein', 'auf'],
#    [None, 'geht', 'ein', 'Verfahren']]],
#  [[[None, 'war', 'ein', 'Test'],
#    [None, 'war', 'ein', 'Test@@'],
#    [None, 'war', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'war', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'war', 'ein', 'Prozess'],
#    [None, 'war', 'ein', 'Pr\xc3\xbcfungs@@'],
#    [None, 'war', 'ein', 'Tag'],
#    [None, 'war', 'ein', 'Grundsatz'],
#    [None, 'war', 'ein', 'test'],
#    [None, 'war', 'ein', 'stest']],
#   [[None, 'war', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'war', 'eine', 'Test@@'],
#    [None, 'war', 'eine', 'Probe'],
#    [None, 'war', 'eine', 'Untersuchung'],
#    [None, 'war', 'eine', 'Frage'],
#    [None, 'war', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'war', 'eine', 'Empfehlung'],
#    [None, 'war', 'eine', 'Studie'],
#    [None, 'war', 'eine', 'Liste'],
#    [None, 'war', 'eine', 'Bewertung']],
#   [[None, 'war', 'einen', 'Test'],
#    [None, 'war', 'einen', 'Test@@'],
#    [None, 'war', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'war', 'einen', 'Tag'],
#    [None, 'war', 'einen', 'test'],
#    [None, 'war', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'war', 'einen', 'stest'],
#    [None, 'war', 'einen', 'Bericht'],
#    [None, 'war', 'einen', 'Prozess'],
#    [None, 'war', 'einen', 'Pr\xc3\xbcfung']],
#   [[None, 'war', 'die', 'Probe'],
#    [None, 'war', 'die', 'Pr\xc3\xbcfung'],
#    [None, 'war', 'die', 'Frage'],
#    [None, 'war', 'die', 'Test@@'],
#    [None, 'war', 'die', 'Konsequenz'],
#    [None, 'war', 'die', 'Durchf\xc3\xbchrung'],
#    [None, 'war', 'die', 'Zeit'],
#    [None, 'war', 'die', 'Empfehlung'],
#    [None, 'war', 'die', 'Annahme'],
#    [None, 'war', 'die', 'Liste']],
#   [[None, 'war', 'einer', 'Pr\xc3\xbcfung'],
#    [None, 'war', 'einer', 'Test@@'],
#    [None, 'war', 'einer', 'der'],
#    [None, 'war', 'einer', 'Test'],
#    [None, 'war', 'einer', 'von'],
#    [None, 'war', 'einer', 'Probe'],
#    [None, 'war', 'einer', 'test'],
#    [None, 'war', 'einer', 'Pr\xc3\xbcf@@'],
#    [None, 'war', 'einer', 'Tests'],
#    [None, 'war', 'einer', 'Pr\xc3\xbcfungen']],
#   [[None, 'war', 'der', 'Test'],
#    [None, 'war', 'der', 'Fall'],
#    [None, 'war', 'der', 'Test@@'],
#    [None, 'war', 'der', 'Pr\xc3\xbcfstand'],
#    [None, 'war', 'der', 'Grundsatz'],
#    [None, 'war', 'der', 'Tag'],
#    [None, 'war', 'der', 'Pr\xc3\xbcf@@'],
#    [None, 'war', 'der', 'Versuch'],
#    [None, 'war', 'der', 'Bericht'],
#    [None, 'war', 'der', 'Preis']],
#   [[None, 'war', 'vor', 'allem'],
#    [None, 'war', 'vor', 'einem'],
#    [None, 'war', 'vor', 'einer'],
#    [None, 'war', 'vor', 'Gericht'],
#    [None, 'war', 'vor', 'dem'],
#    [None, 'war', 'vor', 'Ort'],
#    [None, 'war', 'vor', 'uns'],
#    [None, 'war', 'vor', 'der'],
#    [None, 'war', 'vor', 'kurzem'],
#    [None, 'war', 'vor', 'den']],
#   [[None, 'war', 'es', ','],
#    [None, 'war', 'es', 'eine'],
#    [None, 'war', 'es', 'ein'],
#    [None, 'war', 'es', 'in'],
#    [None, 'war', 'es', 'um'],
#    [None, 'war', 'es', 'vor'],
#    [None, 'war', 'es', 'als'],
#    [None, 'war', 'es', 'mit'],
#    [None, 'war', 'es', 'zu'],
#    [None, 'war', 'es', 'f\xc3\xbcr']],
#   [[None, 'war', 'eines', 'Tages'],
#    [None, 'war', 'eines', 'der'],
#    [None, 'war', 'eines', 'Test'],
#    [None, 'war', 'eines', 'Test@@'],
#    [None, 'war', 'eines', 'von'],
#    [None, 'war', 'eines', 'unserer'],
#    [None, 'war', 'eines', 'pr\xc3\xbcfen'],
#    [None, 'war', 'eines', 'jeden'],
#    [None, 'war', 'eines', 'test'],
#    [None, 'war', 'eines', 'Tests']],
#   [[None, 'war', 'f\xc3\xbcr', 'die'],
#    [None, 'war', 'f\xc3\xbcr', 'einen'],
#    [None, 'war', 'f\xc3\xbcr', 'uns'],
#    [None, 'war', 'f\xc3\xbcr', 'den'],
#    [None, 'war', 'f\xc3\xbcr', 'eine'],
#    [None, 'war', 'f\xc3\xbcr', 'jeden'],
#    [None, 'war', 'f\xc3\xbcr', 'sich'],
#    [None, 'war', 'f\xc3\xbcr', 'ein'],
#    [None, 'war', 'f\xc3\xbcr', 'ihn'],
#    [None, 'war', 'f\xc3\xbcr', 'das']]],
#  [[[None, 'bedeutet', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'bedeutet', 'eine', 'Test@@'],
#    [None, 'bedeutet', 'eine', 'Probe'],
#    [None, 'bedeutet', 'eine', 'Untersuchung'],
#    [None, 'bedeutet', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'bedeutet', 'eine', 'Bewertung'],
#    [None, 'bedeutet', 'eine', 'Probe@@'],
#    [None, 'bedeutet', 'eine', 'Frage'],
#    [None, 'bedeutet', 'eine', 'Stich@@'],
#    [None, 'bedeutet', 'eine', 'Reform']],
#   [[None, 'bedeutet', 'ein', 'Test'],
#    [None, 'bedeutet', 'ein', 'Test@@'],
#    [None, 'bedeutet', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'bedeutet', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'bedeutet', 'ein', 'test'],
#    [None, 'bedeutet', 'ein', 'Probe@@'],
#    [None, 'bedeutet', 'ein', '</S>'],
#    [None, 'bedeutet', 'ein', 'Testen'],
#    [None, 'bedeutet', 'ein', 'Verfahren'],
#    [None, 'bedeutet', 'ein', 'stest']],
#   [[None, 'bedeutet', 'einen', 'Test'],
#    [None, 'bedeutet', 'einen', 'Test@@'],
#    [None, 'bedeutet', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'bedeutet', 'einen', 'test'],
#    [None, 'bedeutet', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'bedeutet', 'einen', 'stest'],
#    [None, 'bedeutet', 'einen', 'Tag'],
#    [None, 'bedeutet', 'einen', 'Pr\xc3\xbcfung'],
#    [None, 'bedeutet', 'einen', 'Prozess'],
#    [None, 'bedeutet', 'einen', 'Bericht']],
#   [[None, 'bedeutet', 'die', 'Pr\xc3\xbcfung'],
#    [None, 'bedeutet', 'die', 'Probe'],
#    [None, 'bedeutet', 'die', 'Test@@'],
#    [None, 'bedeutet', 'die', 'Durchf\xc3\xbchrung'],
#    [None, 'bedeutet', 'die', 'Frage'],
#    [None, 'bedeutet', 'die', 'Notwendigkeit'],
#    [None, 'bedeutet', 'die', 'Annahme'],
#    [None, 'bedeutet', 'die', 'Konsequenz'],
#    [None, 'bedeutet', 'die', 'Stich@@'],
#    [None, 'bedeutet', 'die', 'Reform']],
#   [[None, 'bedeutet', ',', '</S>'],
#    [None, 'bedeutet', ',', 'da\xc3\x9f'],
#    [None, 'bedeutet', ',', 'dass'],
#    [None, 'bedeutet', ',', 'den'],
#    [None, 'bedeutet', ',', 'die'],
#    [None, 'bedeutet', ',', 'einen'],
#    [None, 'bedeutet', ',', 'wie'],
#    [None, 'bedeutet', ',', 'das'],
#    [None, 'bedeutet', ',', 'eine'],
#    [None, 'bedeutet', ',', 'auf']],
#   [[None, 'bedeutet', 'es', ','],
#    [None, 'bedeutet', 'es', '.'],
#    [None, 'bedeutet', 'es', 'zu'],
#    [None, 'bedeutet', 'es', 'eine'],
#    [None, 'bedeutet', 'es', 'f\xc3\xbcr'],
#    [None, 'bedeutet', 'es', 'als'],
#    [None, 'bedeutet', 'es', 'nicht'],
#    [None, 'bedeutet', 'es', '</S>'],
#    [None, 'bedeutet', 'es', 'ein'],
#    [None, 'bedeutet', 'es', 'nur']],
#   [[None, 'bedeutet', 'auf', 'jeden'],
#    [None, 'bedeutet', 'auf', 'einen'],
#    [None, 'bedeutet', 'auf', 'den'],
#    [None, 'bedeutet', 'auf', 'die'],
#    [None, 'bedeutet', 'auf', 'eine'],
#    [None, 'bedeutet', 'auf', 'der'],
#    [None, 'bedeutet', 'auf', 'Test@@'],
#    [None, 'bedeutet', 'auf', 'diesen'],
#    [None, 'bedeutet', 'auf', 'einem'],
#    [None, 'bedeutet', 'auf', 'Probe']],
#   [[None, 'bedeutet', 'f\xc3\xbcr', 'einen'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'die'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'uns'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'den'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'eine'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'jeden'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'sich'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'diesen'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'ein'],
#    [None, 'bedeutet', 'f\xc3\xbcr', 'ihn']],
#   [[None, 'bedeutet', 'auch', 'eine'],
#    [None, 'bedeutet', 'auch', 'einen'],
#    [None, 'bedeutet', 'auch', 'ein'],
#    [None, 'bedeutet', 'auch', 'die'],
#    [None, 'bedeutet', 'auch', ','],
#    [None, 'bedeutet', 'auch', 'f\xc3\xbcr'],
#    [None, 'bedeutet', 'auch', 'den'],
#    [None, 'bedeutet', 'auch', 'der'],
#    [None, 'bedeutet', 'auch', 'auf'],
#    [None, 'bedeutet', 'auch', 'das']],
#   [[None, 'bedeutet', 'vor', 'allem'],
#    [None, 'bedeutet', 'vor', 'einem'],
#    [None, 'bedeutet', 'vor', 'Ort'],
#    [None, 'bedeutet', 'vor', 'dem'],
#    [None, 'bedeutet', 'vor', 'uns'],
#    [None, 'bedeutet', 'vor', 'Gericht'],
#    [None, 'bedeutet', 'vor', 'einer'],
#    [None, 'bedeutet', 'vor', ','],
#    [None, 'bedeutet', 'vor', 'Augen'],
#    [None, 'bedeutet', 'vor', 'den']]],
#  [[[None, 'hier', 'ist', 'ein'],
#    [None, 'hier', 'ist', 'eine'],
#    [None, 'hier', 'ist', 'einer'],
#    [None, 'hier', 'ist', 'die'],
#    [None, 'hier', 'ist', 'der'],
#    [None, 'hier', 'ist', 'einen'],
#    [None, 'hier', 'ist', 'vor'],
#    [None, 'hier', 'ist', 'eines'],
#    [None, 'hier', 'ist', 'es'],
#    [None, 'hier', 'ist', 'nur']],
#   [[None, 'hier', 'geht', 'es'],
#    [None, 'hier', 'geht', 'um'],
#    [None, 'hier', 'geht', 'auf'],
#    [None, 'hier', 'geht', 'ein'],
#    [None, 'hier', 'geht', 'vor'],
#    [None, 'hier', 'geht', 'eine'],
#    [None, 'hier', 'geht', 'nicht'],
#    [None, 'hier', 'geht', 'zu'],
#    [None, 'hier', 'geht', '.'],
#    [None, 'hier', 'geht', '</S>']],
#   [[None, 'hier', 'wird', 'eine'],
#    [None, 'hier', 'wird', 'ein'],
#    [None, 'hier', 'wird', 'vor'],
#    [None, 'hier', 'wird', 'von'],
#    [None, 'hier', 'wird', 'zur'],
#    [None, 'hier', 'wird', 'einen'],
#    [None, 'hier', 'wird', 'auf'],
#    [None, 'hier', 'wird', 'gepr\xc3\xbcft'],
#    [None, 'hier', 'wird', 'sich'],
#    [None, 'hier', 'wird', 'der']],
#   [[None, 'hier', 'sind', 'die'],
#    [None, 'hier', 'sind', 'eine'],
#    [None, 'hier', 'sind', 'ein'],
#    [None, 'hier', 'sind', 'vor'],
#    [None, 'hier', 'sind', 'Test@@'],
#    [None, 'hier', 'sind', 'nur'],
#    [None, 'hier', 'sind', 'Tests'],
#    [None, 'hier', 'sind', 'unsere'],
#    [None, 'hier', 'sind', 'Pr\xc3\xbcf@@'],
#    [None, 'hier', 'sind', 'wir']],
#   [[None, 'hier', 'stellt', 'eine'],
#    [None, 'hier', 'stellt', 'einen'],
#    [None, 'hier', 'stellt', 'ein'],
#    [None, 'hier', 'stellt', 'sich'],
#    [None, 'hier', 'stellt', 'die'],
#    [None, 'hier', 'stellt', 'es'],
#    [None, 'hier', 'stellt', 'einer'],
#    [None, 'hier', 'stellt', 'vor'],
#    [None, 'hier', 'stellt', 'das'],
#    [None, 'hier', 'stellt', 'uns']],
#   [[None, 'hier', 'liegt', 'ein'],
#    [None, 'hier', 'liegt', 'auf'],
#    [None, 'hier', 'liegt', 'bei'],
#    [None, 'hier', 'liegt', 'eine'],
#    [None, 'hier', 'liegt', 'in'],
#    [None, 'hier', 'liegt', 'vor'],
#    [None, 'hier', 'liegt', '</S>'],
#    [None, 'hier', 'liegt', 'an'],
#    [None, 'hier', 'liegt', 'einen'],
#    [None, 'hier', 'liegt', 'nicht']],
#   [[None, 'hier', 'handelt', 'sich'],
#    [None, 'hier', 'handelt', 'es'],
#    [None, 'hier', 'handelt', 'von'],
#    [None, 'hier', 'handelt', '</S>'],
#    [None, 'hier', 'handelt', '.'],
#    [None, 'hier', 'handelt', 'eine'],
#    [None, 'hier', 'handelt', 'ist'],
#    [None, 'hier', 'handelt', 'um'],
#    [None, 'hier', 'handelt', 'ein'],
#    [None, 'hier', 'handelt', 'auf']],
#   [[None, 'hier', 'gilt', '</S>'],
#    [None, 'hier', 'gilt', 'als'],
#    [None, 'hier', 'gilt', 'f\xc3\xbcr'],
#    [None, 'hier', 'gilt', 'ein'],
#    [None, 'hier', 'gilt', ','],
#    [None, 'hier', 'gilt', '.'],
#    [None, 'hier', 'gilt', 'eine'],
#    [None, 'hier', 'gilt', 'nur'],
#    [None, 'hier', 'gilt', 'auch'],
#    [None, 'hier', 'gilt', 'es']],
#   [[None, 'hier', 'war', 'ein'],
#    [None, 'hier', 'war', 'eine'],
#    [None, 'hier', 'war', 'einer'],
#    [None, 'hier', 'war', 'die'],
#    [None, 'hier', 'war', 'einen'],
#    [None, 'hier', 'war', 'der'],
#    [None, 'hier', 'war', 'vor'],
#    [None, 'hier', 'war', 'eines'],
#    [None, 'hier', 'war', 'es'],
#    [None, 'hier', 'war', 'Test']],
#   [[None, 'hier', 'hat', 'eine'],
#    [None, 'hier', 'hat', 'sich'],
#    [None, 'hier', 'hat', 'einen'],
#    [None, 'hier', 'hat', 'ein'],
#    [None, 'hier', 'hat', 'die'],
#    [None, 'hier', 'hat', 'es'],
#    [None, 'hier', 'hat', 'das'],
#    [None, 'hier', 'hat', 'zur'],
#    [None, 'hier', 'hat', 'der'],
#    [None, 'hier', 'hat', 'vor']]],
#  [[[None, 'gilt', 'f\xc3\xbcr', 'einen'],
#    [None, 'gilt', 'f\xc3\xbcr', 'eine'],
#    [None, 'gilt', 'f\xc3\xbcr', 'die'],
#    [None, 'gilt', 'f\xc3\xbcr', 'ein'],
#    [None, 'gilt', 'f\xc3\xbcr', 'den'],
#    [None, 'gilt', 'f\xc3\xbcr', 'jeden'],
#    [None, 'gilt', 'f\xc3\xbcr', 'das'],
#    [None, 'gilt', 'f\xc3\xbcr', 'unsere'],
#    [None, 'gilt', 'f\xc3\xbcr', 'uns'],
#    [None, 'gilt', 'f\xc3\xbcr', 'unseren']],
#   [[None, 'gilt', 'als', 'ein'],
#    [None, 'gilt', 'als', 'Test'],
#    [None, 'gilt', 'als', 'eine'],
#    [None, 'gilt', 'als', 'Test@@'],
#    [None, 'gilt', 'als', 'f\xc3\xbcr'],
#    [None, 'gilt', 'als', 'Pr\xc3\xbcf@@'],
#    [None, 'gilt', 'als', 'Pr\xc3\xbcfung'],
#    [None, 'gilt', 'als', 'die'],
#    [None, 'gilt', 'als', 'Pr\xc3\xbcfstand'],
#    [None, 'gilt', 'als', 'vor']],
#   [[None, 'gilt', 'auch', 'f\xc3\xbcr'],
#    [None, 'gilt', 'auch', 'bei'],
#    [None, 'gilt', 'auch', 'als'],
#    [None, 'gilt', 'auch', 'auf'],
#    [None, 'gilt', 'auch', 'in'],
#    [None, 'gilt', 'auch', 'daf\xc3\xbcr'],
#    [None, 'gilt', 'auch', 'zur'],
#    [None, 'gilt', 'auch', 'nicht'],
#    [None, 'gilt', 'auch', 'von'],
#    [None, 'gilt', 'auch', 'nur']],
#   [[None, 'gilt', 'ein', 'Test'],
#    [None, 'gilt', 'ein', 'Test@@'],
#    [None, 'gilt', 'ein', 'f\xc3\xbcr'],
#    [None, 'gilt', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'gilt', 'ein', 'von'],
#    [None, 'gilt', 'ein', '</S>'],
#    [None, 'gilt', 'ein', '.'],
#    [None, 'gilt', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'gilt', 'ein', 'zur'],
#    [None, 'gilt', 'ein', 'auf']],
#   [[None, 'gilt', 'nur', 'f\xc3\xbcr'],
#    [None, 'gilt', 'nur', 'bei'],
#    [None, 'gilt', 'nur', 'auf'],
#    [None, 'gilt', 'nur', 'als'],
#    [None, 'gilt', 'nur', 'zur'],
#    [None, 'gilt', 'nur', 'in'],
#    [None, 'gilt', 'nur', 'daf\xc3\xbcr'],
#    [None, 'gilt', 'nur', 'durch'],
#    [None, 'gilt', 'nur', 'zu'],
#    [None, 'gilt', 'nur', ',']],
#   [[None, 'gilt', 'bei', 'einem'],
#    [None, 'gilt', 'bei', 'der'],
#    [None, 'gilt', 'bei', 'den'],
#    [None, 'gilt', 'bei', 'einer'],
#    [None, 'gilt', 'bei', 'uns'],
#    [None, 'gilt', 'bei', 'dem'],
#    [None, 'gilt', 'bei', 'unseren'],
#    [None, 'gilt', 'bei', 'allen'],
#    [None, 'gilt', 'bei', 'Test@@'],
#    [None, 'gilt', 'bei', '30']],
#   [[None, 'gilt', 'es', 'f\xc3\xbcr'],
#    [None, 'gilt', 'es', 'als'],
#    [None, 'gilt', 'es', ','],
#    [None, 'gilt', 'es', 'zu'],
#    [None, 'gilt', 'es', '.'],
#    [None, 'gilt', 'es', 'bei'],
#    [None, 'gilt', 'es', 'in'],
#    [None, 'gilt', 'es', 'zur'],
#    [None, 'gilt', 'es', 'auf'],
#    [None, 'gilt', 'es', 'zum']],
#   [[None, 'gilt', 'vor', 'einem'],
#    [None, 'gilt', 'vor', 'allem'],
#    [None, 'gilt', 'vor', 'dem'],
#    [None, 'gilt', 'vor', 'Ort'],
#    [None, 'gilt', 'vor', 'einer'],
#    [None, 'gilt', 'vor', 'als'],
#    [None, 'gilt', 'vor', 'Gericht'],
#    [None, 'gilt', 'vor', 'allen'],
#    [None, 'gilt', 'vor', 'der'],
#    [None, 'gilt', 'vor', 'den']],
#   [[None, 'gilt', 'in', 'einem'],
#    [None, 'gilt', 'in', 'der'],
#    [None, 'gilt', 'in', 'den'],
#    [None, 'gilt', 'in', 'einer'],
#    [None, 'gilt', 'in', 'unseren'],
#    [None, 'gilt', 'in', 'Test@@'],
#    [None, 'gilt', 'in', 'erster'],
#    [None, 'gilt', 'in', 'Zeiten'],
#    [None, 'gilt', 'in', 'dem'],
#    [None, 'gilt', 'in', 'allen']],
#   [[None, 'gilt', 'auf', 'einem'],
#    [None, 'gilt', 'auf', 'den'],
#    [None, 'gilt', 'auf', 'dem'],
#    [None, 'gilt', 'auf', 'die'],
#    [None, 'gilt', 'auf', 'jeden'],
#    [None, 'gilt', 'auf', 'einen'],
#    [None, 'gilt', 'auf', 'Test@@'],
#    [None, 'gilt', 'auf', 'der'],
#    [None, 'gilt', 'auf', 'eine'],
#    [None, 'gilt', 'auf', 'Probe']]],
#  [[[None, 'betrifft', 'die', 'Pr\xc3\xbcfung'],
#    [None, 'betrifft', 'die', 'Test@@'],
#    [None, 'betrifft', 'die', 'Probe'],
#    [None, 'betrifft', 'die', 'Durchf\xc3\xbchrung'],
#    [None, 'betrifft', 'die', 'Tests'],
#    [None, 'betrifft', 'die', 'Ergebnisse'],
#    [None, 'betrifft', 'die', 'Stich@@'],
#    [None, 'betrifft', 'die', 'Pr\xc3\xbcfungen'],
#    [None, 'betrifft', 'die', 'Versuche'],
#    [None, 'betrifft', 'die', 'Frage']],
#   [[None, 'betrifft', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'betrifft', 'eine', 'Test@@'],
#    [None, 'betrifft', 'eine', 'Probe'],
#    [None, 'betrifft', 'eine', 'Untersuchung'],
#    [None, 'betrifft', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'betrifft', 'eine', 'Bewertung'],
#    [None, 'betrifft', 'eine', 'Tests'],
#    [None, 'betrifft', 'eine', 'Probe@@'],
#    [None, 'betrifft', 'eine', 'Stich@@'],
#    [None, 'betrifft', 'eine', 'Pr\xc3\xbcfungen']],
#   [[None, 'betrifft', 'einen', 'Test@@'],
#    [None, 'betrifft', 'einen', 'Test'],
#    [None, 'betrifft', 'einen', 'test'],
#    [None, 'betrifft', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'betrifft', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'betrifft', 'einen', 'Tag'],
#    [None, 'betrifft', 'einen', 'stest'],
#    [None, 'betrifft', 'einen', 'Pr\xc3\xbcfungs@@'],
#    [None, 'betrifft', 'einen', 'Prozess'],
#    [None, 'betrifft', 'einen', 'Bericht']],
#   [[None, 'betrifft', 'den', 'Test'],
#    [None, 'betrifft', 'den', 'Pr\xc3\xbcfstand'],
#    [None, 'betrifft', 'den', 'Tag'],
#    [None, 'betrifft', 'den', 'Test@@'],
#    [None, 'betrifft', 'den', 'Pr\xc3\xbcf@@'],
#    [None, 'betrifft', 'den', 'Grundsatz'],
#    [None, 'betrifft', 'den', 'Bericht'],
#    [None, 'betrifft', 'den', 'Proze\xc3\x9f'],
#    [None, 'betrifft', 'den', 'Stand'],
#    [None, 'betrifft', 'den', 'Fall']],
#   [[None, 'betrifft', 'ein', 'Test@@'],
#    [None, 'betrifft', 'ein', 'Test'],
#    [None, 'betrifft', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'betrifft', 'ein', 'Pr\xc3\xbcfungs@@'],
#    [None, 'betrifft', 'ein', 'test'],
#    [None, 'betrifft', 'ein', 'Verfahren'],
#    [None, 'betrifft', 'ein', '</S>'],
#    [None, 'betrifft', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'betrifft', 'ein', 'Probe@@'],
#    [None, 'betrifft', 'ein', 'Thema']],
#   [[None, 'betrifft', 'das', '</S>'],
#    [None, 'betrifft', 'das', 'Thema'],
#    [None, 'betrifft', 'das', 'Test@@'],
#    [None, 'betrifft', 'das', 'Verfahren'],
#    [None, 'betrifft', 'das', 'Prinzip'],
#    [None, 'betrifft', 'das', 'Testen'],
#    [None, 'betrifft', 'das', 'Pr\xc3\xbcf@@'],
#    [None, 'betrifft', 'das', 'Experiment'],
#    [None, 'betrifft', 'das', '.'],
#    [None, 'betrifft', 'das', 'Gebot']],
#   [[None, 'betrifft', 'vor', 'allem'],
#    [None, 'betrifft', 'vor', 'Ort'],
#    [None, 'betrifft', 'vor', 'dem'],
#    [None, 'betrifft', 'vor', 'einem'],
#    [None, 'betrifft', 'vor', 'Gericht'],
#    [None, 'betrifft', 'vor', 'uns'],
#    [None, 'betrifft', 'vor', 'den'],
#    [None, 'betrifft', 'vor', 'der'],
#    [None, 'betrifft', 'vor', 'einer'],
#    [None, 'betrifft', 'vor', 'allen']],
#   [[None, 'betrifft', 'auf', 'jeden'],
#    [None, 'betrifft', 'auf', 'den'],
#    [None, 'betrifft', 'auf', 'die'],
#    [None, 'betrifft', 'auf', 'einen'],
#    [None, 'betrifft', 'auf', 'der'],
#    [None, 'betrifft', 'auf', 'diesen'],
#    [None, 'betrifft', 'auf', 'diese'],
#    [None, 'betrifft', 'auf', 'dem'],
#    [None, 'betrifft', 'auf', 'Test@@'],
#    [None, 'betrifft', 'auf', 'unseren']],
#   [[None, 'betrifft', 'nur', 'die'],
#    [None, 'betrifft', 'nur', 'den'],
#    [None, 'betrifft', 'nur', 'eine'],
#    [None, 'betrifft', 'nur', 'einen'],
#    [None, 'betrifft', 'nur', 'ein'],
#    [None, 'betrifft', 'nur', 'dann'],
#    [None, 'betrifft', 'nur', 'das'],
#    [None, 'betrifft', 'nur', '</S>'],
#    [None, 'betrifft', 'nur', 'noch'],
#    [None, 'betrifft', 'nur', 'diese']],
#   [[None, 'betrifft', 'es', ','],
#    [None, 'betrifft', 'es', '.'],
#    [None, 'betrifft', 'es', 'als'],
#    [None, 'betrifft', 'es', 'eine'],
#    [None, 'betrifft', 'es', 'einen'],
#    [None, 'betrifft', 'es', 'in'],
#    [None, 'betrifft', 'es', 'mit'],
#    [None, 'betrifft', 'es', 'nur'],
#    [None, 'betrifft', 'es', '</S>'],
#    [None, 'betrifft', 'es', 'vor']]],
#  [[[None, 'hat', 'eine', 'Pr\xc3\xbcfung'],
#    [None, 'hat', 'eine', 'Test@@'],
#    [None, 'hat', 'eine', 'Probe'],
#    [None, 'hat', 'eine', 'Frage'],
#    [None, 'hat', 'eine', 'Untersuchung'],
#    [None, 'hat', 'eine', '\xc3\x9cberpr\xc3\xbcfung'],
#    [None, 'hat', 'eine', 'Empfehlung'],
#    [None, 'hat', 'eine', 'Konsequenz'],
#    [None, 'hat', 'eine', 'Tests'],
#    [None, 'hat', 'eine', 'Bewertung']],
#   [[None, 'hat', 'einen', 'Test'],
#    [None, 'hat', 'einen', 'Test@@'],
#    [None, 'hat', 'einen', 'Tag'],
#    [None, 'hat', 'einen', 'Pr\xc3\xbcf@@'],
#    [None, 'hat', 'einen', 'Pr\xc3\xbcfstand'],
#    [None, 'hat', 'einen', 'stest'],
#    [None, 'hat', 'einen', 'test'],
#    [None, 'hat', 'einen', 'guten'],
#    [None, 'hat', 'einen', 'festen'],
#    [None, 'hat', 'einen', 'Pr\xc3\xbcfung']],
#   [[None, 'hat', 'die', 'Probe'],
#    [None, 'hat', 'die', 'Frage'],
#    [None, 'hat', 'die', 'Pr\xc3\xbcfung'],
#    [None, 'hat', 'die', 'Konsequenz'],
#    [None, 'hat', 'die', 'Kommission'],
#    [None, 'hat', 'die', 'Situation'],
#    [None, 'hat', 'die', 'Notwendigkeit'],
#    [None, 'hat', 'die', 'Zeit'],
#    [None, 'hat', 'die', 'M\xc3\xb6glichkeit'],
#    [None, 'hat', 'die', 'Durchf\xc3\xbchrung']],
#   [[None, 'hat', 'ein', 'Test@@'],
#    [None, 'hat', 'ein', 'Test'],
#    [None, 'hat', 'ein', 'Pr\xc3\xbcf@@'],
#    [None, 'hat', 'ein', 'Pr\xc3\xbcfungs@@'],
#    [None, 'hat', 'ein', 'Experiment'],
#    [None, 'hat', 'ein', 'Pr\xc3\xbcfstand'],
#    [None, 'hat', 'ein', 'Testen'],
#    [None, 'hat', 'ein', 'Verfahren'],
#    [None, 'hat', 'ein', 'Ende'],
#    [None, 'hat', 'ein', 'Pr\xc3\xbc@@']],
#   [[None, 'hat', 'sich', 'auf'],
#    [None, 'hat', 'sich', 'f\xc3\xbcr'],
#    [None, 'hat', 'sich', 'auch'],
#    [None, 'hat', 'sich', 'eine'],
#    [None, 'hat', 'sich', 'hier'],
#    [None, 'hat', 'sich', 'zur'],
#    [None, 'hat', 'sich', 'um'],
#    [None, 'hat', 'sich', 'in'],
#    [None, 'hat', 'sich', 'mit'],
#    [None, 'hat', 'sich', 'ein']],
#   [[None, 'hat', 'es', 'hier'],
#    [None, 'hat', 'es', 'um'],
#    [None, 'hat', 'es', 'mit'],
#    [None, 'hat', 'es', 'sich'],
#    [None, 'hat', 'es', 'auch'],
#    [None, 'hat', 'es', 'zu'],
#    [None, 'hat', 'es', 'in'],
#    [None, 'hat', 'es', 'zur'],
#    [None, 'hat', 'es', 'einen'],
#    [None, 'hat', 'es', 'sein']],
#   [[None, 'hat', 'das', 'Thema'],
#    [None, 'hat', 'das', 'Verfahren'],
#    [None, 'hat', 'das', 'Problem'],
#    [None, 'hat', 'das', 'Prinzip'],
#    [None, 'hat', 'das', 'Gebot'],
#    [None, 'hat', 'das', 'Experiment'],
#    [None, 'hat', 'das', 'ist'],
#    [None, 'hat', 'das', '</S>'],
#    [None, 'hat', 'das', 'Testen'],
#    [None, 'hat', 'das', 'zur']],
#   [[None, 'hat', 'zur', 'Zeit'],
#    [None, 'hat', 'zur', 'Folge'],
#    [None, 'hat', 'zur', 'Pr\xc3\xbcfung'],
#    [None, 'hat', 'zur', 'Konsequenz'],
#    [None, 'hat', 'zur', 'Tat'],
#    [None, 'hat', 'zur', 'Probe'],
#    [None, 'hat', 'zur', 'Frage'],
#    [None, 'hat', 'zur', 'Test@@'],
#    [None, 'hat', 'zur', 'Gesch\xc3\xa4ftsordnung'],
#    [None, 'hat', 'zur', 'Praxis']],
#   [[None, 'hat', 'auch', 'einen'],
#    [None, 'hat', 'auch', 'eine'],
#    [None, 'hat', 'auch', 'die'],
#    [None, 'hat', 'auch', 'ein'],
#    [None, 'hat', 'auch', 'f\xc3\xbcr'],
#    [None, 'hat', 'auch', 'noch'],
#    [None, 'hat', 'auch', 'zur'],
#    [None, 'hat', 'auch', 'hier'],
#    [None, 'hat', 'auch', 'das'],
#    [None, 'hat', 'auch', 'auf']],
#   [[None, 'hat', 'auf', 'jeden'],
#    [None, 'hat', 'auf', 'einen'],
#    [None, 'hat', 'auf', 'den'],
#    [None, 'hat', 'auf', 'der'],
#    [None, 'hat', 'auf', 'die'],
#    [None, 'hat', 'auf', 'einem'],
#    [None, 'hat', 'auf', 'unseren'],
#    [None, 'hat', 'auf', 'eine'],
#    [None, 'hat', 'auf', 'diesen'],
#    [None, 'hat', 'auf', 'dem']]]]

# %%
start_hyp.payload
